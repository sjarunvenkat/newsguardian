# 24  I want blackpink to do only a single show in I...   shootforbeepee
# 25  Prime Minister Narendra Modi on Monday a sanda...        MirrorNow
# 26  Probably a satire...\nCongress leader Rajeev S...      ARIEL_SIDON
# 27  @nytimes @NickKristof @KenRoth Please understa...     Vikraant3737
# 28  No cakewalk for Narendra Modi winning 2024 Lok...        nishaDev1
# 29  PM Narendra Modi Gifts Sandalwood Buddha Statu...        ramankk92
# 30  @RahulGandhi Modi is not India - Narendra Modi...   MediaMainstage
# 31  PM Narendra Modi meets Fumio Kishida, announce...    TheAJShow2023
# 32  @IndiaToday @rohit_manas But till recently he ...       sumitsonii
# 33  In his keynote address at the #IndiaTodayConcl...       IndiaToday
# 34  Economics-The Big Take:The Global Economy Need...  reachind_USACAN
# 35  @RahulGandhi In you, Italian blood is running ...    PrithviSkills
# 36  NEW DELHI — Japan’s Prime Minister Fumio Kishi...       seaman1243
# 37  Narendra Modi invites you to an interesting fo...  DevarshiJoshi17
# 38  The Caravan has published a copy of an inquiry...  thecaravanindia
# 39  #NariShakti\n\nNarendra Modi government  -\nSt...  DevarshiJoshi17
# 40  PM #narendramodi is reverentially referred to ...         narain41
# 41  @Paul_Koshy Exactly - for Narendra Modi to WIN...     batobatomein
# 42  Scamster Mehul Choksi removed from Interpol da...        AR__yadav
# 43  PM Narendra Modi ji with prime minister of Jap...       Seversingh
# 44  Many people might be scared of the BJP, Narend...        SevadalDL
# 45  @RahulGandhi Yes, the Prime Minister is not In...  JeyaseelanKanag
# 46  11. Fumio Kishida\n\n📊 Detailed Stats: https:/...    24TrendsIndia
# 47  @TrueIndology 1. Krishnaraja Wodeyar (based on...   PanditRamJoshi
# 48  Hot🔥 : Japanese PM Fumio Kishida tries 'Gol Ga...     IndiaSpeaksR
# 49  Let's put it straight.\nPointing/calling out t...       t_d_h_nair
# 50  @ARIEL_SIDON @t_d_h_nair @aroonpurie But sir,t...           mds174

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk import re
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
MIN_YEAR = 1900
MAX_YEAR = 2100
def get_url_patern():
    return re.compile(
        r'(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))'
        r'[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9]\.[^\s]{2,})')

def get_emojis_pattern():
    try:
        # UCS-4
        emojis_pattern = re.compile(u'([\U00002600-\U000027BF])|([\U0001f300-\U0001f64F])|([\U0001f680-\U0001f6FF])')
    except re.error:
        # UCS-2
        emojis_pattern = re.compile(
            u'([\u2600-\u27BF])|([\uD83C][\uDF00-\uDFFF])|([\uD83D][\uDC00-\uDE4F])|([\uD83D][\uDE80-\uDEFF])')
    return emojis_pattern

def get_hashtags_pattern():
    return re.compile(r'#\w*')

def get_single_letter_words_pattern():
    return re.compile(r'(?<![\w\-])\w(?![\w\-])')

# %%
def get_blank_spaces_pattern():
    return re.compile(r'\s{2,}|\t')

def get_twitter_reserved_words_pattern():
    return re.compile(r'(RT|rt|FAV|fav|VIA|via)')

def is_year(text):
    if (len(text) == 3 or len(text) == 4) and (MIN_YEAR < len(text) < MAX_YEAR):
        return True
    else:
        return False

# %% [markdown]
# #### Class Twitter Preprocessor

# %%
class TwitterPreprocessor:

    def __init__(self, text: str):
        self.text = text

    def fully_preprocess(self):
        return self \
            .remove_urls() \
            .remove_mentions() \
            .remove_hashtags() \
            .remove_twitter_reserved_words() \
            .remove_punctuation() \
            .remove_single_letter_words() \
            .remove_blank_spaces() \
            .remove_stopwords() \
            .remove_numbers()

    def remove_urls(self):
        self.text = re.sub(pattern=get_url_patern(), repl='', string=self.text)
        return self

    def remove_punctuation(self):
        self.text = self.text.translate(str.maketrans('', '', string.punctuation))
        return self

    def remove_mentions(self):
        self.text = re.sub(pattern=get_mentions_pattern(), repl='', string=self.text)
        return self

    def remove_hashtags(self):
        self.text = re.sub(pattern=get_hashtags_pattern(), repl='', string=self.text)
        return self

    def remove_twitter_reserved_words(self):
        self.text = re.sub(pattern=get_twitter_reserved_words_pattern(), repl='', string=self.text)
        return self

    def remove_single_letter_words(self):
        self.text = re.sub(pattern=get_single_letter_words_pattern(), repl='', string=self.text)
        return self

    def remove_blank_spaces(self):
        self.text = re.sub(pattern=get_blank_spaces_pattern(), repl=' ', string=self.text)
        return self

    def remove_stopwords(self, extra_stopwords=None):
        if extra_stopwords is None:
            extra_stopwords = []
        text = nltk.word_tokenize(self.text)
        stop_words = set(stopwords.words('english'))

        new_sentence = []
        for w in text:
            if w not in stop_words and w not in extra_stopwords:
                new_sentence.append(w)
        self.text = ' '.join(new_sentence)
        return self

    def remove_numbers(self, preserve_years=False):
        text_list = self.text.split(' ')
        for text in text_list:
            if text.isnumeric():
                if preserve_years:
                    if not is_year(text):
                        text_list.remove(text)
                else:
                    text_list.remove(text)

        self.text = ' '.join(text_list)
        return self

    def lowercase(self):
        self.text = self.text.lower()
        return self

# %%
# Clean tweets and append to new column
tweets = df['Text']
clean_tweets = []
for tweet in tweets:
    c = TwitterPreprocessor((tweet))
    c.fully_preprocess()
    c = c.text
    clean_tweets.append(c)
    
df['clean_tweets'] = clean_tweets 
df.head(5)
# Out:
#                    Datetime             Tweet Id  \
# 0 2023-03-20 23:52:49+00:00  1637965446996537344
# 1 2023-03-20 22:53:39+00:00  1637950559134294016
# 2 2023-03-20 22:52:41+00:00  1637950315822727168
# 3 2023-03-20 22:48:43+00:00  1637949317645488129
# 4 2023-03-20 22:16:14+00:00  1637941143836016642
#
#                                                 Text      Username  \
# 0  Interestingly, it is the Congress-led Chhattis...     BasuAshis
# 1  @tis_sjoberg @taylorswift13 dude I will litera...  2amandrain13
# 2  Soros has been blamed for the financial collap...     dom_lucre
# 3  @tis_sjoberg @contrarian_sh1t @taylorswift13 D...     Gooner_AS
# 4  ‘Deal With PM Narendra Modi’: Congress Hits Ou...     SnahaDey1
#
#                                         clean_tweets
# 0  Interestingly Congressled Chhattisgarh governm...
# 1  dude literally kill narendra modi stadium mayb...
# 2  Soros blamed financial collapse countries incl...
# 3  DY Patil ’ host international games Narendra M...
# 4  ‘ Deal With PM Narendra Modi ’ Congress Hits O...

# %%
df2 = list(df['clean_tweets'])

# %%
type(df2)
# Out:
# list

# %%
df2 = pd.DataFrame(df2)
df2.columns = ['first']

df2.head()
# Out:
#                                                first
# 0  Interestingly Congressled Chhattisgarh governm...
# 1  dude literally kill narendra modi stadium mayb...
# 2  Soros blamed financial collapse countries incl...
# 3  DY Patil ’ host international games Narendra M...
# 4  ‘ Deal With PM Narendra Modi ’ Congress Hits O...

# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.9/dist-packages (1.7.0)

# %%
import emoji
df2['first'] = df2['first'].apply(lambda s: emoji.replace_emoji(s, ''))
df2.head(10)
# Out:
#                                                first
# 0  Interestingly Congressled Chhattisgarh governm...
# 1  dude literally kill narendra modi stadium mayb...
# 2  Soros blamed financial collapse countries incl...
# 3  DY Patil ’ host international games Narendra M...
# 4  ‘ Deal With PM Narendra Modi ’ Congress Hits O...
# 5  The captioned video Pieter Friedrich activist ...
# 6  It ’ great failure Australian Prime Minister A...
# 7  TATA IPL  The 16th season marquee event kickst...
# 8  Why comment either Sri Narendra Modihis Cabine...
# 9  In September Biden told Narendra Modi prime mi...

# %%
seventeen = df2.values.tolist()

print(seventeen[1][0])
# Out:
# dude literally kill narendra modi stadium maybe dy patil wankhede dont live Mumbai though Id much prefer narendra modi stadium

# %% [markdown]
# ## Apply profanity here on the list called TEN.

# %%
ten = []

for i in range(0, len(seventeen)):
  ten.append(seventeen[i][0])


ten
# Out:
# ['Interestingly Congressled Chhattisgarh government time taken Prime Minister Narendra Modi Bharatiya Janata Pay BJP ouring Adani group given project goahead',
#  'dude literally kill narendra modi stadium maybe dy patil wankhede dont live Mumbai though Id much prefer narendra modi stadium ',
#  'Soros blamed financial collapse countries including Indonesia Thailand Japan Malaysia Russia India expressing strong protest George Soross recent comments Narendra Modi also covered past media doesnt',
#  'DY Patil ’ host international games Narendra Modi stadium set host ICC World Cup final later year yeah chance conce happens international cricket stadium India',
#  '‘ Deal With PM Narendra Modi ’ Congress Hits Out At TMC After Mamata Banerjee Targets Rahul Gandhi India News',
#  'The captioned video Pieter Friedrich activist writer delivering fiery speech Houston City Council exposing alleged genocide engineered Indian PM Narendra Modi Rashtriya Swayamsevak Sangh RSS rightwing Hindu nationalist group',
#  'It ’ great failure Australian Prime Minister Anthony Albanese tells Hon ’ ble Prime Minister Narendra Modi cant stop ISI amp Pakistan sponsored SFJ Referendum Khalistan voting proKhalistan Sikhs Brisbane',
#  'TATA IPL  The 16th season marquee event kicksta 31st March blockbuster clash Gujarat Titans Chennai Super Kings Ahmedabad Narendra Modi Stadium largest cricket stadium world',
#  'In keynote address PM Narendra Modi spoke length achievements government Indias rising stature global order promise coupled performance backbone India moment',
#  'EconomicsThe Big TakeThe Global Economy Needs New Powerhouse India Is Stepping Up Prime Minister Narendra Modi Wants Make India Developed Nation How Soon Country Synonymous Red Tape become trillion Economy',
#  'In Italian blood running truth You never PM mother democracy INDIA keep ever acting suppoers actually jealous Statesman Shri Narendra Modi Ji  You perish flowu junk',
#  'NEW DELHI — Japan ’ Prime Minister Fumio Kishida Monday invited Indian counterpa Narendra Modi Group Seven major industrial nations summit May later expected announce new plan free open…',
#  'Narendra Modi invites interesting forum Addressing press meet PM NaMo App',
#  'The Caravan published copy inquiry conducted government United Kingdom Gujarat violence cited recent BBC documentary Prime Minister Narendra Modi titled India The Modi Question Read repo',
#  'Narendra Modi government Strengthening effos amp giving new momentum womenled development MyNt',
#  'PM reverentially referred The Immoal Chinese netizens according journalist Mu Chushan writing The Diplomat In aicle How India viewed China PM Narendra Modi referred Modi Laoxian meanin…',
#  'Exactly Narendra Modi WIN plus Lok Sabha seats hypocrites enteained India',
#  'Scamster Mehul Choksi removed Interpol database Red Corner Notice travel across world freely Scamster Mehul close Narendra Modi used refer Mehul Bhai even Govt programmes',
#  'PM Narendra Modi ji prime minister Japan kishida enjoyed Indian snacks including Golgappas',
#  'Many people might scared BJP Narendra Modi RSS amp Police scared least scared thats problem You pressurise terrorise believe fight truth BJP burning country',
#  'Yes Prime Minister India All BJP personnel wrongly think criticism Narendra Modi Government criticism India antiIndia PM criticism paicularly opposition paies also law',
#  'Fumio Kishida  Detailed Stats  News Related Times India Japanese PM Fumio Kishida enjoys Pani Puri PM Narendra Modi',
#  'Krishnaraja Wodeyar based previous thread Sardar Patel Narendra Modi',
#  'Hot Japanese PM Fumio Kishida tries Gol Gappe PM Narendra Modi Buddha Jayanti Park Delhi twodayvisit India posted uVividAdvisor888',
#  'Lets put straight Pointingcalling scams atrocities propagatedorchestrated Narendra Modi govts criticising India Only bhakts Godi media journalists live delusions Narendra Modi India India Narendra Modi',
#  'But sirthe proof given one making claim How one prove Narendra Modi visit hisher placeIt ModiPurie give proof every district Btw Rajasthan getting new districts Modi ji making plans']

# %%
# !pip install profanity-check
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting profanity-check
#   Downloading profanity_check-1.0.3-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.2 in /usr/local/lib/python3.9/dist-packages (from profanity-check) (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.2->profanity-check) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.2->profanity-check) (1.24.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.2->profanity-check) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.2->profanity-check) (1.1.1)
# Installing collected packages: profanity-check
# Successfully installed profanity-check-1.0.3

# %%
# !pip install better-profanity
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting better-profanity
#   Downloading better_profanity-0.7.0-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 KB 3.1 MB/s eta 0:00:00
# Installing collected packages: better-profanity
# Successfully installed better-profanity-0.7.0

# %%
from better_profanity import profanity

# %%
thirtythree = []

for i in range(0, len(ten)):
  vone = profanity.contains_profanity(ten[i])
  thirtythree.append(vone)

# %%
thirtythree
